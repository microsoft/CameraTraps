# %%
import pickle
catLookup = {'human_bike': 'human',
             'human_ohv': 'car',
             'spotted_skunk': 'skunk',
             'gray_squirrel': 'squirrel',
             'DIVI_opossum': 'opossum',
             'ROSP_ratlike': 'rodent',
             'mouse_or_rat': 'rodent',
             'rat': 'rodent',
             #'rodent': 'rodent',
             'mouse': 'rodent',
             'Rat': 'rodent',
             'SUSC_pig': 'pig',
             'grayfox': 'fox',
             'california_towhee': 'bird',
             'northern_flicker': 'bird',
             'scrub_jay': 'bird',
             'mule_deer': 'deer',
             'thrasher': 'bird',
             'whiptail': 'lizard',
             'fence_lizard': 'lizard',
             'wren': 'bird',
             'woodrat': 'rodent',
             'WoodRat': 'rodent',
             'raven': 'bird',
             'crow': 'bird',
             'hawk': 'bird',
             'road runner': 'bird',
             'burrowing_owl': 'bird',
             'kangaroo_rat': 'rodent',
             'quail': 'bird',
             'mourning_dove': 'bird',
             'spotted_towhee': 'bird',
             'sparrow': 'bird',
             'hummingbird': 'bird',
             'white_crowned_sparrow': 'bird',
             'california_thrasher': 'bird',
             'black-hooded_parakeet': 'bird',
             'western_meadowlark': 'bird',
             'bluejay': 'bird',
             'jay': 'bird',
             'rock_sparrow': 'bird',
             'fox_sparrow': 'bird',
             'california_mouse': 'rodent',
             'oak_titmouse': 'bird',
             'dove': 'bird',
             'owl': 'bird',
             'northern_mockingbird': 'bird',
             'coyote_pup': 'coyote',
             'sage_thrasher': 'bird',
             'common_poorwill': 'bird',
             'acorn_woodpecker': 'bird',
             'flicker': 'bird',
             'rock_wren': 'bird',
             'california_quail': 'bird',
             'american_goldfinch': 'bird',
             'thrush': 'bird',
             'finch': 'bird',
             'field_mouse': 'rodent',
             'house_finch': 'bird',
             'red_fox': 'fox',
             'meadowlark': 'bird',
             'chicken': 'bird',
             'black-headed_grossbeak': 'bird',
             'great_egret': 'bird',
             'barn_owl': 'bird',
             'kit_fox': 'fox',
#              'burro': 'burro'
             'kangaroo_rat': 'rodent',
             'antelope_squirrel': 'squirrel',
             'northern_harrier': 'bird',
             'red-tailed_hawk': 'bird',
             'cowbird': 'bird',
             'great_blue_heron': 'bird',
             'golden_eagle': 'bird',
             'chukar': 'bird',
             'cliff_chipmunk': 'chipmunk',
             'clarks_nutcracker': 'bird',
             'woodpecker': 'bird',
             'horned_owl': 'bird',
             'belted_kingfisher': 'bird',
             'robin': 'bird',
             'coot': 'bird',
             'pinyon_jay': 'bird',
             'coopers_hawk': 'bird',
             'turkey_vulture': 'bird',
             'cottontail': 'rabbit',
             'desert_cottontail': 'rabbit',
             'trip': 'empty',
             'junk': 'empty',
             'unknown': 'empty',
             'blur': 'empty',
             'fox_squirrel':'squirrel',
             'hermit_thrush':'bird',
             'striped_skunk': 'skunk',
             'jackrabbit':'rabbit',
             'dark-eyed_junco': 'bird',
             'black_phoebe': 'bird',
             'white-crowned_sparrow': 'bird',
             'brush_rabbit': 'rabbit',
             'western_scrub_jay': 'bird',
             'ground_dove': 'bird',
             'yellow-rumped_warbler': 'bird',
             'american_robin': 'bird',
             'deer_mouse': 'rodent',
             'gnatcatcher': 'bird',
#              'black_bear': 'bear',
             'butterfly': 'insect',
             'moth': 'insect',
             'small mammal': 'rodent',
             'unknown_animal': 'empty'
             }
pickle.dump(catLookup, open('big_category_lookup.p','wb'))
